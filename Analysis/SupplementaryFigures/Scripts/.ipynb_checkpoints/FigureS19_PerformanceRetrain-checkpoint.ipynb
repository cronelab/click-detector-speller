# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import scipy
import statistics

from scipy.stats import bootstrap

# %% [markdown]
# # USING PANDAS TO IMPORT SWITCH SCANNER METRICS

# %%
# Defining the pathway to the switch scanner metrics.
path_switchscan_metrics = '../SourceData/switch_scanner_metrics_retrain.xlsx'

# Importing the excel sheets for 4 vote and 7 vote thresholds.
df_6thr_1000ms = pd.read_excel(path_switchscan_metrics, '6_votes')

# Extracting only the summary rows for each day.
df_6thr_summary = df_6thr_1000ms.loc[df_6thr_1000ms['Date'].str.contains('Total'),:]


# Remove the "_Total" suffix from each date.
df_6thr_summary['Date'] = df_6thr_summary['Date'].str.replace('_Total', '')
# Out:
# /tmp/ipykernel_1013132/1257124451.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_6thr_summary['Date'] = df_6thr_summary['Date'].str.replace('_Total', '')

# %%
def extracting_latencies(date_block_dict, dir_base, folder, movement):
    """
    DESCRIPTION:
    Extracting all the latencies from the experimenter-input blocks into one array.
    
    INPUT VARIABLES:
    date_block_dict: [dictionary (keys: strings (dates); values: list > ints (blocks)]; Dictionary of dates and blocks corresponding to each date. 
    dir_base:        [string]; Base directory where all information for this subject and task (Speller) is found.
    movement:        [string]; The movement from which the onsets and offsets will be extracted.

    OUTPUT VARIABLES:
    latencies_arr: [array > floats (units: s)]; Array of latencies from all experimenter-input blocks.
    """

    # COMPUTATION:
    
    # Initializing the list of latencies.
    list_of_latencies = []

    # Iterating across all dates. 
    for date in date_block_dict.keys():

        # Extracting the block list from dictionary.
        block_list = date_block_dict[date]

        # Iterating across all blocks from the current block list.
        for block in block_list:

            # Creating the pathway for the .txt file where the starting and ending times of the current block are stored.
            this_directory       = dir_base + date + '/' + folder + '/'
            this_filename        = date + '_' + 'click_latencies'
            path_click_latencies = this_directory + this_filename

            # Read in the dictionary from the pathway.
            with open(path_click_latencies, "rb") as fp:   
                dict_click_latencies = pickle.load(fp)

            # Extracting the click latencies from the dictionary.
            t_click_latencies = dict_click_latencies[movement]['block'+str(block)]

            # Adding the array of click latencies to the list.
            list_of_latencies.append(t_click_latencies)

    # Concatenating the arrays from the list into one array.
    latencies_arr = np.hstack(list_of_latencies)
    
    return latencies_arr

# %%
color1a = 'navy' # blue
color1b = 'royalblue' #cornflowerblue
color2a = 'darkcyan' # green
color2b = 'lightseagreen' # lightgreen

marker1 = 'o'
marker2 = '^'

save_figs = False



days_post_training_6thr  = np.asarray(df_6thr_summary['Days Post-Training']).astype(float)
tpf_6thr                 = np.asarray(df_6thr_summary['TPF ( /min)']).astype(float)
fpf_6thr                 = np.asarray(df_6thr_summary['FPF ( /min)']).astype(float)
sensitivity_6thr         = np.asarray(df_6thr_summary['Sensitivity (%)']).astype(float)
mean_latency_BCI2K_6thr  = np.asarray(df_6thr_summary['Mean Latency to BCI2000 (s)'].values).astype(float)
stdev_latency_BCI2K_6thr = np.asarray(df_6thr_summary['Stdev Latency to BCI2000 (s)'].values).astype(float)
mean_latency_UI_6thr     = np.asarray(df_6thr_summary['Mean Latency to UI (s)'].values).astype(float)
stdev_latency_UI_6thr    = np.asarray(df_6thr_summary['Stdev Latency to UI (s)'].values).astype(float)
ccpm_6thr                = np.asarray(df_6thr_summary['Correct CPM']).astype(float)
wcpm_6thr                = np.asarray(df_6thr_summary['Wrong CPM']).astype(float)
cwpm_6thr                = np.asarray(df_6thr_summary['Correct WPM']).astype(float)



fig, ax = plt.subplots(5,1, figsize=(8,10))
fig.tight_layout(pad=3)

# ROW 1: SENSITIVITY
ax[0].scatter(days_post_training_6thr, sensitivity_6thr, color = color1b, edgecolors='black', linewidths=0.75, marker=marker1, zorder=2)
ax[0].set_yticks(np.arange(70,101,10)) 
ax[0].set_ylim([70, 105])
ax[0].set_ylabel('Sensitivity (%)')
ax[0].spines[['right', 'top']].set_visible(False)
ax[0].yaxis.label.set_color('k') 
ax[0].tick_params(axis='y', colors='k')
ax[0].spines['left'].set_color('k') 
ax[0].grid(axis='y', linestyle='dashed', dashes=(15, 20), linewidth=0.5)
print('Median Sensitivity (6-vote threshold): ', statistics.median(sensitivity_6thr))

# ROW 2: TPF and FPF
ax[1].grid(axis='y', linestyle='dashed', dashes=(15, 20), linewidth=0.5)
ax[1].scatter(days_post_training_6thr, tpf_6thr, color = color1b, edgecolors='black', linewidths=0.75, marker=marker1, zorder=2)
ax[1].scatter(days_post_training_6thr, fpf_6thr, color = color2b, edgecolors='black', linewidths=0.75, marker=marker1, zorder=2)
ax[1].set_ylabel('Click rate (/min)')
ax[1].set_yticks(np.arange(0,16,5))
ax[1].set_ylim([-1, 15])
ax[1].spines[['top', 'right']].set_visible(False)
print('TPF and FPF:')
print('Median TPF (6-vote threshold): ', statistics.median(tpf_6thr))
print('Median FPF (6-vote threshold): ', statistics.median(fpf_6thr))
print('\n\n')


# ROW 3: BCI2000 and UI LATENCIES
shift = 0 #0.10
dir_base = '../SourceData/ClickLatencies/'
# Creating lists of UI latencies to plot as box and whisker plots for the 4-vote threshold.
latencies_ui_6thr = []
latencies_bci2k_6thr = []
for this_date in df_6thr_summary['Date']:
    
    # Initializing and populating the dictionary that will hold the date and block numbers.
    date_block_dict = {}
    date_block_dict[this_date] = np.array([df_6thr_1000ms.loc[np.where(df_6thr_1000ms['Date'] == this_date)[0][0]]['Block']])
    
    # Extracitng the BCI2000 and UI latencies for the current date.
    this_date_6thr_latencies_bci2k = extracting_latencies(date_block_dict, dir_base, 'BCI2000', 'grasp')
    this_date_6thr_latencies_ui = extracting_latencies(date_block_dict, dir_base, 'UI', 'grasp')
    
    # Appending the lists of latencies to the corresponding lists.
    latencies_bci2k_6thr.append(this_date_6thr_latencies_bci2k)
    latencies_ui_6thr.append(this_date_6thr_latencies_ui)
                             
# ax[2].boxplot(latencies_bci2k_6thr,\
#               showfliers=False, positions=days_post_training_6thr-shift, manage_ticks=False, widths=0.5, patch_artist=True,\
#               boxprops=dict(facecolor=color2a, color='black', alpha = 0.5),\
#               capprops=dict(color='black', alpha = 0.5),\
#               whiskerprops=dict(color='black', alpha = 0.5),\
#               medianprops=dict(color='black', linewidth=2.0, alpha = 0.5))
# ax[2].scatter(days_post_training_6thr-shift, mean_latency_BCI2K_6thr, color = color2b, edgecolors='black', marker=marker1, linewidths=0.75, zorder=3)

ax[2].boxplot(latencies_ui_6thr,\
              showfliers=False, positions=days_post_training_6thr+shift, manage_ticks=False, widths=0.5, patch_artist=True,\
              boxprops=dict(facecolor=color1a, color='black', alpha = 0.5),\
              capprops=dict(color='black', alpha = 0.5),\
              whiskerprops=dict(color='black', alpha = 0.5),\
              medianprops=dict(color='black', linewidth=2.0, alpha = 0.5))
ax[2].scatter(days_post_training_6thr+shift, mean_latency_UI_6thr, color = color1b, edgecolors='black', marker=marker1, linewidths=0.75, zorder=3)

ax[2].set_ylabel('Click Latencies (s)')
ax[2].set_yticks(np.array([0.25, 0.5, 0.75, 1, 1.25])) 
ax[2].set_ylim([0.20, 1.3])
ax[2].tick_params(axis='y', colors='k')
ax[2].spines[['top']].set_visible(False)
ax[2].spines[['top', 'right']].set_visible(False)
ax[2].yaxis.label.set_color('k') 
ax[2].grid(axis='y', linestyle='dashed', zorder=1, dashes=(15, 20), linewidth=0.5)
print('Median BCI2000 Latency across session means (6-vote threshold):', statistics.median(mean_latency_BCI2K_6thr))
print('Median UI Latency across session means (6-vote threshold):', statistics.median(mean_latency_UI_6thr))
print('\n\n')

# ROW 4: CCPM and WCPM
ax[3].grid(axis='y', linestyle='dashed', dashes=(15, 20), linewidth=0.5)
ax[3].scatter(days_post_training_6thr, ccpm_6thr, color = color1b, edgecolors='black', linewidths=0.75, marker=marker1, zorder=2)
ax[3].scatter(days_post_training_6thr, wcpm_6thr, color = color2b, edgecolors='black', linewidths=0.75, marker=marker1, zorder=2)
ax[3].set_ylabel('CPM (/min)')
ax[3].set_yticks(np.arange(0,15,2.5)) 
ax[3].set_ylim([-0.5, 12])
ax[3].spines[['top', 'right']].set_visible(False)
print('CCPM and WCPM:')
print('Median CCPM (6-vote threshold): ', statistics.median(ccpm_6thr))
print('Median WCPM (6-vote threshold): ', statistics.median(wcpm_6thr))
print('\n\n')



# ROW 5: CWPM (Correct words per min)
ax[4].grid(axis='y', linestyle='dashed', dashes=(15, 20), linewidth=0.5)
ax[4].scatter(days_post_training_6thr, cwpm_6thr, color = color1b, edgecolors='black', linewidths=0.75, marker=marker1, zorder=2)
ax[4].set_ylabel('CWPM (/min)')
ax[4].set_yticks(np.arange(0,3.1,1)) 
ax[4].set_ylim([0, 3])
ax[4].tick_params(axis='y', colors='k')
ax[4].spines[['top', 'right']].set_visible(False)
ax[4].set_xlabel('Days')
print('CWPM:')
print('Median CWPM (6-vote threshold): ', statistics.median(cwpm_6thr))
print('\n\n')





# Subfigure labels.
fig.text(0.025, 0.96, 
         'a', 
         style = 'normal',
         fontsize = 12,
         color = "black",
         weight = 'bold')
fig.text(0.025, 0.78, 
         'b', 
         style = 'normal',
         fontsize = 12,
         color = "black",
         weight = 'bold')
fig.text(0.025, 0.58, 
         'c', 
         style = 'normal',
         fontsize = 12,
         color = "black",
         weight = 'bold')
fig.text(0.025, 0.39, 
         'd', 
         style = 'normal',
         fontsize = 12,
         color = "black",
         weight = 'bold')
fig.text(0.025, 0.20, 
         'e', 
         style = 'normal',
         fontsize = 12,
         color = "black",
         weight = 'bold')


if save_figs: 
    fig.savefig('SummaryMetricsFigure_Retrain.jpg', bbox_inches = 'tight', dpi=1000)
    fig.savefig('SummaryMetricsFigure_Retrain.svg', format = 'svg', bbox_inches = 'tight', dpi=1000)
# Out:
# Median Sensitivity (6-vote threshold):  95.03284072249589
# TPF and FPF:
# Median TPF (6-vote threshold):  11.506541149354938
# Median FPF (6-vote threshold):  0.048950261639148465
#
#
#
# Median BCI2000 Latency across session means (6-vote threshold): 0.72
# Median UI Latency across session means (6-vote threshold): 0.869
#
#
#
# CCPM and WCPM:
# Median CCPM (6-vote threshold):  10.07750176588978
# Median WCPM (6-vote threshold):  0.10053374623908151
#
#
#
# CWPM:
# Median CWPM (6-vote threshold):  2.163410246322065

# %% [markdown]
# # 95% Confidence Interval of the Median for Performance Metrics

# %%
n_resamples = 10000

ci_95_sensitivity_6thr = bootstrap((sensitivity_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_tpf_6thr = bootstrap((tpf_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_fpf_6thr = bootstrap((fpf_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_bci2k_lat_6thr = bootstrap((mean_latency_BCI2K_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_ui_lat_6thr = bootstrap((mean_latency_UI_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_ccpm_6thr = bootstrap((ccpm_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_wcpm_6thr = bootstrap((wcpm_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

ci_95_cwpm_6thr = bootstrap((cwpm_6thr,), np.mean, confidence_level=0.95, n_resamples=n_resamples).confidence_interval

print('95% CI Sensitivity (6-vote): ', ci_95_sensitivity_6thr)

print('95% CI TPF (6-vote): ', ci_95_tpf_6thr)

print('95% CI FPF (6-vote): ', ci_95_fpf_6thr)

print('95% CI BCI2000 latency (6-vote): ', ci_95_bci2k_lat_6thr)

print('95% CI UI latency (6-vote): ', ci_95_ui_lat_6thr)

print('95% CI CCPM (6-vote): ', ci_95_ccpm_6thr)

print('95% CI WCPM (6-vote): ', ci_95_wcpm_6thr)

print('95% CI CWPM (6-vote): ', ci_95_cwpm_6thr)
# Out:
# 95% CI Sensitivity (6-vote):  ConfidenceInterval(low=91.52041123585839, high=95.88221127531472)
# 95% CI TPF (6-vote):  ConfidenceInterval(low=10.97923010311975, high=11.844364850672697)
# 95% CI FPF (6-vote):  ConfidenceInterval(low=0.03263350775943231, high=0.5335960258002914)
# 95% CI BCI2000 latency (6-vote):  ConfidenceInterval(low=0.6751666666666667, high=0.7651666666666669)
# 95% CI UI latency (6-vote):  ConfidenceInterval(low=0.8633333333333333, high=0.9136666666666667)
# 95% CI CCPM (6-vote):  ConfidenceInterval(low=9.016660383545165, high=10.603351362182286)
# 95% CI WCPM (6-vote):  ConfidenceInterval(low=0.07473801359951643, high=0.5548849594952846)
# 95% CI CWPM (6-vote):  ConfidenceInterval(low=1.9518393470289517, high=2.4111728353913424)

# %% [markdown]
# # Extracting performance metrics from original model with 4-vote threshold

# %%
path_switchscan_metrics_orig = '../../MainFigures/SourceData/switch_scanning_spelling_metrics.xlsx'

# Importing the excel sheets for 4 vote thresholds.
df_4thr_1000ms_orig = pd.read_excel(path_switchscan_metrics_orig, '4_votes')

# Extracting only the summary rows for each day.
df_4thr_summary_orig = df_4thr_1000ms_orig.loc[df_4thr_1000ms_orig['Date'].str.contains('Total'),:]

# Remove the "_Total" suffix from each date.
df_4thr_summary_orig['Date'] = df_4thr_summary_orig['Date'].str.replace('_Total', '')

days_post_training_4thr_orig  = np.asarray(df_4thr_summary_orig['Days Post-Training']).astype(float)
tpf_4thr_orig                 = np.asarray(df_4thr_summary_orig['TPF ( /min)']).astype(float)
fpf_4thr_orig                 = np.asarray(df_4thr_summary_orig['FPF ( /min)']).astype(float)
sensitivity_4thr_orig         = np.asarray(df_4thr_summary_orig['Sensitivity (%)']).astype(float)
mean_latency_BCI2K_4thr       = np.asarray(df_4thr_summary_orig['Mean Latency to BCI2000 (s)'].values).astype(float)
mean_latency_UI_4thr          = np.asarray(df_4thr_summary_orig['Mean Latency to UI (s)'].values).astype(float)
ccpm_4thr_orig                = np.asarray(df_4thr_summary_orig['Correct CPM']).astype(float)
wcpm_4thr_orig                = np.asarray(df_4thr_summary_orig['Wrong CPM']).astype(float)
cwpm_4thr_orig                = np.asarray(df_4thr_summary_orig['Correct WPM']).astype(float)
# Out:
# /tmp/ipykernel_1013132/1300725215.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4thr_summary_orig['Date'] = df_4thr_summary_orig['Date'].str.replace('_Total', '')

# %% [markdown]
# # Wilcoxon Rank-Sum Test for Performance Metrics

# %%
print(sensitivity_6thr.mean(), sensitivity_4thr_orig.mean())
print(tpf_6thr.mean(), tpf_4thr_orig.mean())
print(fpf_6thr.mean(), fpf_4thr_orig.mean())
print(mean_latency_BCI2K_6thr.mean(), mean_latency_BCI2K_4thr.mean())
print(mean_latency_UI_6thr.mean(), mean_latency_UI_4thr.mean())
print(ccpm_6thr.mean(), ccpm_4thr_orig.mean())
print(wcpm_6thr.mean(), wcpm_4thr_orig.mean())
print(cwpm_6thr.mean(), cwpm_4thr_orig.mean())

print('Wilcoxon Rank-Sum (Sensitivity):', scipy.stats.ranksums(sensitivity_6thr, sensitivity_4thr_orig))
print('Wilcoxon Rank-Sum (TPF):', scipy.stats.ranksums(tpf_6thr, tpf_4thr_orig))
print('Wilcoxon Rank-Sum (FPF):', scipy.stats.ranksums(fpf_6thr, fpf_4thr_orig))
print('Wilcoxon Rank-sum (BCI2000 latencies): ', scipy.stats.ranksums(mean_latency_BCI2K_6thr, mean_latency_BCI2K_4thr))
print('Wilcoxon Rank-sum (UI latencies): ', scipy.stats.ranksums(mean_latency_UI_6thr, mean_latency_UI_4thr))
print('Wilcoxon Rank-Sum (CCPM):', scipy.stats.ranksums(ccpm_6thr, ccpm_4thr_orig))
print('Wilcoxon Rank-Sum (WCPM):', scipy.stats.ranksums(wcpm_6thr, wcpm_4thr_orig))
print('Wilcoxon Rank-Sum (CWPM):', scipy.stats.ranksums(cwpm_6thr, cwpm_4thr_orig))
# Out:
# 94.30045809890684 96.48553743679804
# 11.427998742717664 11.510166549768991
# 0.16215598505000836 0.17032502720426124
# 0.7200000000000001 0.4757777777777778
# 0.8816666666666667 0.6726666666666667
# 9.938292431534093 10.18867624472134
# 0.251930991654798 0.14103528062337592
# 2.1392215475142655 2.172755966219656
# Wilcoxon Rank-Sum (Sensitivity): RanksumsResult(statistic=-1.885618083164127, pvalue=0.05934643879191985)
# Wilcoxon Rank-Sum (TPF): RanksumsResult(statistic=0.11785113019775793, pvalue=0.9061856157549283)
# Wilcoxon Rank-Sum (FPF): RanksumsResult(statistic=-1.0017346066809425, pvalue=0.31647178784797814)
# Wilcoxon Rank-sum (BCI2000 latencies):  RanksumsResult(statistic=3.1819805153394642, pvalue=0.001462716586681149)
# Wilcoxon Rank-sum (UI latencies):  RanksumsResult(statistic=3.1819805153394642, pvalue=0.001462716586681149)
# Wilcoxon Rank-Sum (CCPM): RanksumsResult(statistic=-0.47140452079103173, pvalue=0.6373518882339371)
# ...
